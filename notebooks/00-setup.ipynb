# %% [markdown]
# # 00 — Setup & sanity checks
#
# This notebook verifies your environment and the local `quantum_ed` package.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import quantum_ed
print('quantum_ed imported:', quantum_ed.__file__)

# %%
from quantum_ed.gates import H
from quantum_ed.linalg import is_unitary
print('H is unitary:', is_unitary(H))

# %% [markdown]
# ✅ If the import works and tests pass, you're ready.
#
# Next: `01-qubit-bloch.ipynb`
